// %% [markdown]
// # Lab 5.1 การวาด flowchart ด้วย mermaid diagram

// %% [markdown]
// ## 5
// .1.1 องค์ประกอบต่างๆ ของการวาด flowchart

// %% [markdown]
// ศึกษาจากตัวอย่างแผนภาพอย่างง่ายต่อไปนี้ โดยการรัน code cell ด้านล่างนี้ (โดยการเข้าไปใน cell แล้วกด Ctrl+Enter)
//
// __หมายเหตุ__ นักศึกษาสามารถล้างผลการรันทั้งหมดได้โดยการกดปุ่ม _Clear All Outputs_  ที่ด้านบนของเอกสาร

// %%
%% Example 1. Flow chart
flowchart TD
    A[Start] --> B{Today = Workday}
    B -- Yes --> C[Goto school]
    B -- No --> D[Goto picnic]
    C --> E[Back to home]
    D --> E
    E --> F[End]

// %% [markdown]
// ### อธิบาย Code ตามรูปแบบสัญลักษณ์ที่ปรากฏใน code
// จาก code และรูปที่ได้จากการรัน สามารถอธิบายส่วนต่างๆ ตามไวยากรณ์ได้ดังนี้
//
// 1. `flowchart TD` ป็นคำสั่งที่ใช้ในการสร้าง แผนภูมิลำดับขั้นตอน (flowchart) ที่มีทิศทางจาก บนลงล่าง (top-down)
// 2. `A[start]` เป็นการกำหนดโหนด A ที่มีลักษณะเป็นกล่องสี่เหลี่ยม มีคำว่า Start อยู่ด้านใน
// 3. `-->` เป็นการระบุว่าลากเส้นลูกศรจากโหนด A ไปโหนด B
// 4. `B{Today = Workday}` เป็นการสร้างโหนด B ซึ่งเป็นบล็อกของการตัดสินใจ
// 5. `-- Yes --> หรือ -- NO -->` เป็นการลากเส้นลูกศรที่มีข้อความ Yes หรือ No กำกับ

// %% [markdown]
// คักลอก code จากตัวอย่าง Example 1 มาไว้ในพื้นที่แก้ไข code ด้านล่าง แล้วแก้ไข code ตามนี้
// > ```diff
// > - flowchart TD
// > + flowchart LR
// > ```

// %% [markdown]
// _หมายเหตุ_ จากคำสั่งด้านบน หมายความว่า ให้ลบบรรทัด flowchart TD แล้วเพิ่ม flowchart LR ที่ตำแหน่งเดิม
//
// หมายถึงการแก้ไขบรรทัดนั้นจาก flowchart TD เป็น flowchart LR นั่นเอง
//
// ซึ่งเป็นรูปแบบของการระบุการเปลี่ยนแปลงเนื้อหาใน git

// %%
%% Example 1. Flow chart
flowchart LR
    A[Start] --> B{Today = Workday}
    B -- Yes --> C[Goto school]
    B -- No --> D[Goto picnic]
    C --> E[Back to home]
    D --> E
    E --> F[End]

// %% [markdown]
// หมายเหตุ ถ้ารันไม่ได้ หรือมี error เช่นในลักษณะนี้
// > ```
// > Error: (1,1): error CS1525: Invalid expression term '%'
// > (1,2): error CS1525: Invalid expression term '%'
// > (1,17): error CS1002: ; expected
// > ```
//
// ปัญหาเกิดจากการเลือกภาษาเป็น csharp ให้คลิกเลือกภาษาจากมุมขวาล่างของ code cell โดยเปลี่ยนเป็นภาษา mermaid

// %% [markdown]
// #### คำถาม
//
// 1. บรรทัดที่ขึ้นต้นด้วย %% มีการแแสดงผลที่ output หรือไม่ ถ้ามี จะแสดงอย่างไร
// 2. บอกข้อแตกต่างระหว่าง flowchart TD และ flowchart LR

// %% [markdown]
// คำถาม
//
//
// 1.บรรทัดที่ขึ้นต้นด้วย %% มีการแแสดงผลที่ output หรือไม่ ถ้ามี จะแสดงอย่างไร
//
// ตอบ ไม่มีการแสดงผลที่ Output เมื่อรันโค้ดจะสามารถรันได้ปกติไม่เกิด error แต่อย่างใด
//
// 2.บอกข้อแตกต่างระหว่าง flowchart TD และ flowchart LR
//
// ตอบ flowchart TD จะแสดงข้อมูลจากบนลงล่าง ส่วน flowchart LR จะแสดงข้อมูลจากซ้ายไปขวา

// %% [markdown]
// ---

// %% [markdown]
// ## Flowcharts - Basic Syntax

// %% [markdown]
// #### 1 Node

// %% [markdown]
// รัน code cell ด้านล่าง เพื่อดูผลที่ได้ และตอบคำถาม

// %% [markdown]
// _Example 2_

// %%
---
title: Node
---
flowchart LR
    id

// %% [markdown]
// __คำถาม__
//
// 1. ข้อความต่อไปนี้คืออะไร มีการแสดงที่ output หรือไม่
// > ```
// > ---
// > title: Node
// > ---
// > ```
//
// 2. ข้อความ id มีการแสดงนำไปแสดงผลที่ output หรือไม่ แสดงเป็นอะไร

// %% [markdown]
// 1.ตอบ คือชื่อของเอกสาร มีการแสดงผลที่ output ว่า Node อยู่ด้านบน id
//
// 2.ตอบ มีการแสดงผล id อยู่ในกรอบสี่เหลี่ยมการทำ flowchart

// %% [markdown]
// ---

// %% [markdown]
// #### 2. Node ที่มีข้อความกำกับ

// %% [markdown]
// จาก Example 2 ให้แก้ข้อความดังนี้
// > ```diff
// > ---
// > title: Node
// > ---
// > flowchart LR
// > -    id
// > +    id[Happy New Year]
// > ```

// %%
---
title: Node
---
flowchart LR

id[Happy New Year]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="d466847c691a44a7b02639000ab68c3b"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('d466847c691a44a7b02639000ab68c3b');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_d466847c691a44a7b02639000ab68c3b',
//                     `---
// title: Node
// ---
// flowchart LR
//
// id[Happy New Year]`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// จาก code ด้านบน  ให้แก้เป็นดังต่อไปนี้
// > ```diff
// > ---
// > title: Node
// > ---
// > flowchart LR
// > -    id[Happy New Year]
// > +    id [Happy New Year]
// > ```

// %%
---
title: Node
---

flowchart LR
id [Happy New Year]
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="12443811a1084002a8b6842426d21fb6"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('12443811a1084002a8b6842426d21fb6');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_12443811a1084002a8b6842426d21fb6',
//                     `---
// title: Node
// ---
//
// flowchart LR
// id [Happy New Year]`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// __คำถาม__
//
// เมื่อรัน code cell ด้านบน ผลที่ได้แตกต่างจาก Example 2  อย่างไร

// %% [markdown]
// ---

// %% [markdown]
// ตอบ โค้ดที่แก้ไขด้วยการใช้คำสั่ง id[Happy New Year]สามารถรันออกมาได้ แต่เมื่อเปลี่ยนเป็น id [Happy New Year]ไม่สามารถรันโค้ดได้ ผลลัพธ์ต่างจาก example 2 ที่ชื่อในกล่อง id มีคำว่า Happy New Year แทนที่คำว่า id

// %% [markdown]
// #### 3. การกำหนดทิศทางของ flow

// %% [markdown]
// สร้าง code cell และเขียน code ภาษา mermaid ดังนี้
// > ```
// > flowchart TD
// >     Start --> Stop
// > ```

// %%
flowchart TD
     Start --> Stop
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="50c3316999ed4a888ae151389a9a1032"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('50c3316999ed4a888ae151389a9a1032');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_50c3316999ed4a888ae151389a9a1032',
//                     `flowchart TD
//      Start --> Stop`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// แก้ไข code ด้านบนดังนี้
// > ```diff
// > - flowchart TD
// > + flowchart LR
// >     Start --> Stop
// > ```

// %%
flowchart LR
    Start --> Stop
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="91f4a095b438432dbe5831e868efaf90"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('91f4a095b438432dbe5831e868efaf90');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_91f4a095b438432dbe5831e868efaf90',
//                     `flowchart LR
//     Start --> Stop`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ___คำถาม___
//
// flowchart TD และ flowchart LR ให้ผลแตกต่างกันอย่างไร

// %% [markdown]
// ตอบ TD ให้ผลการรันเรียงเป็นแถวแนวตั้งบนลงล่าง ส่วนต่างกันที่ LR เรียงเป็นแถวแนวนอนจากซ้ายไปขวา

// %% [markdown]
// ---

// %% [markdown]
// #### 4. รูปร่างของ Node

// %% [markdown]
// รัน code cell ต่อไปนี้

// %%
flowchart LR
    id1(This is the text in the box)
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="aadd5b6f55384d6184e14a75ad2e7d26"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('aadd5b6f55384d6184e14a75ad2e7d26');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_aadd5b6f55384d6184e14a75ad2e7d26',
//                     `flowchart LR
//     id1(This is the text in the box)`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// อธิบายรูปร่างที่ได้

// %% [markdown]
// มีกล่องข้อความสี่เหลี่ยมที่มีความโค้งมนมีข้อความข้างในว่า This is text in the box

// %% [markdown]
// แก้ไข code ด้านบน เป็นดังต่อไปนี้
// > ```diff
// > flowchart LR
// > -    id1(This is the text in the box)
// > +    d1([This is the text in the box])
// > ```

// %%
flowchart LR
    d1([This is the text in the box])
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="89a573f561fa454cb3474e694771ad7a"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('89a573f561fa454cb3474e694771ad7a');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_89a573f561fa454cb3474e694771ad7a',
//                     `flowchart LR
//     d1([This is the text in the box])`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// อธิบายรูปร่างที่ได้

// %% [markdown]
// มีกล่องข้อความสี่เหลี่ยมที่มีความโค้งมนมาก คล้ายterminator ที่มีข้อความข้างในว่า This is text in the box

// %% [markdown]
// ให้สร้าง code cell แล้วนำ code จากตารางต่อไปนี้ไปวางใน code cell เหล่านั้น

// %% [markdown]
// |รูปร่าง|เครื่องหมายที่ใช้|Code|
// |---|:---------:|---|
// |วงกลม| ((...))| flowchart LR<br><dd>id1((This is the text in the circle)) </dd>|
// |ทรงกระบอก| [(...)] |  flowchart LR <br> <dd>id1[(Database)]</dd>|
// |ป้ายกำกับ| >...]  |  flowchart LR <br> <dd>id1>This is the text in the box]</dd>|
// |การตัดสินใจ |{...} |  flowchart LR <br> <dd> id1{This is the text in the box} </dd>|
// |hexagon |{{...}} |  flowchart LR <br> <dd> {{This is the text in the box}} </dd>|
// | Parallelogram|[/.../] |  flowchart LR <br> <dd> id1[/This is the text in the box/]</dd>|
// | Parallelogram alt| [\...\]|  flowchart LR <br> <dd> id1[\This is the text in the box\]</dd>|
// |Trapezoid | [/...\]|  flowchart LR <br> <dd>A[/Christmas\]  </dd>|
// |Trapezoid alt | [\.../]|  flowchart LR <br> <dd>B[\Go shopping/]  </dd>|
// |Double circle| (((...)))|  flowchart LR <br> <dd> id1(((This is the text in the circle))) </dd>|

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา flowchart จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagramพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ## 1. ให้ค้นหา flowchart จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image-3.png](attachment:image-3.png)

// %% [markdown]
// ## 2. เขียน code ในภาษา mermaid diagramพื่อวาดตามไดอะแกรมนั้น

// %%
flowchart TD
    Start([START])
    GetAge[Get car's Age]
    GetMileage[Get car's Mileage]
    Decision{IF Age > 2 OR Mileage > 200,000}
    Service[Perform car service]
    NoService[Not perform car service]
    Stop([STOP])

    Start --> GetAge --> GetMileage --> Decision
    Decision -->|YES| Service --> Stop
    Decision -->|NO| NoService --> Stop
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="9c20e862857940d4b93815c80d4a8714"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('9c20e862857940d4b93815c80d4a8714');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_9c20e862857940d4b93815c80d4a8714',
//                     `flowchart TD
//     Start([START])
//     GetAge[Get car's Age]
//     GetMileage[Get car's Mileage]
//     Decision{IF Age > 2 OR Mileage > 200,000}
//     Service[Perform car service]
//     NoService[Not perform car service]
//     Stop([STOP])
//
//     Start --> GetAge --> GetMileage --> Decision
//     Decision -->|YES| Service --> Stop
//     Decision -->|NO| NoService --> Stop
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
flowchart TD
    Start([เริ่มต้น])
    Test[ทดสอบ]
    Check[ตรวจผลการสอบและคัดคะแนนที่สอบได้]
    Decision{คะแนน < 50?}
    Fail[พิมพ์ สอบไม่ผ่าน]
    Pass[พิมพ์ สอบผ่าน]
    End([จบ])

    Start --> Test --> Check --> Decision
    Decision -->|จริง| Fail --> End
    Decision -->|เท็จ| Pass --> End
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="f0c6911f3b4441de98d97f4da6e9365c"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('f0c6911f3b4441de98d97f4da6e9365c');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_f0c6911f3b4441de98d97f4da6e9365c',
//                     `flowchart TD
//     Start([เริ่มต้น])
//     Test[ทดสอบ]
//     Check[ตรวจผลการสอบและคัดคะแนนที่สอบได้]
//     Decision{คะแนน < 50?}
//     Fail[พิมพ์ สอบไม่ผ่าน]
//     Pass[พิมพ์ สอบผ่าน]
//     End([จบ])
//
//     Start --> Test --> Check --> Decision
//     Decision -->|จริง| Fail --> End
//     Decision -->|เท็จ| Pass --> End
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
graph TD
    A[Task 1] --> B[Task 2]
    B --> C[Task 3]
    C --> D[Task 4]
    D -->|Yes| E{Is Service Request Bit Set?}
    E -->|Yes| F[Execute ISR / Task 5]
    F --> G[Task 6]
    E -->|No| G
    G --> H[Task 7]
    H --> I[Task 8]
    I --> J[Task 9]
    J --> A
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="fe944c0baf5c49ee9f8c2cf5e4903543"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('fe944c0baf5c49ee9f8c2cf5e4903543');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_fe944c0baf5c49ee9f8c2cf5e4903543',
//                     `graph TD
//     A[Task 1] --> B[Task 2]
//     B --> C[Task 3]
//     C --> D[Task 4]
//     D -->|Yes| E{Is Service Request Bit Set?}
//     E -->|Yes| F[Execute ISR / Task 5]
//     F --> G[Task 6]
//     E -->|No| G
//     G --> H[Task 7]
//     H --> I[Task 8]
//     I --> J[Task 9]
//     J --> A
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ## 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ### ศึกษาเพิ่มเติม
//
// https://mermaid.js.org/syntax/flowchart.html
