// %% [markdown]
// # Lab 5.2 การวาด class diagram ด้วย mermaid diagram

// %% [markdown]
// ## 5.2.1 องค์ประกอบใน class diagram

// %% [markdown]
// ### 1. Class

// %% [markdown]
// การวาด class diagram ใน mermaid มี keywords ที่สำคัญคือ
// 1. ต้องระบุ __ชนิดของไดะแกรม__ ด้วยคีย์เวิร์ด `classDiagram`
// 2. ต้องระบุ __ชื่อคลาส__ ด้วยคีย์เวิร์ด `class`

// %%
classDiagram
    class Animal

// %% [markdown]
// แก้ code จากด้านบนเป็น
// > ```diff
// > classDiagram
// > -    class Animal
// > +    class Vehicle
// > +    class Computer
// > ```

// %%
classDiagram
    class Vehicle
    class Computer

// %% [markdown]
// ---

// %% [markdown]
// ### 2. Class label

// %% [markdown]
// โดยปกติ ชื่อคลาสต้องไม่มีช่องว่างภายในชื่อ ในกรณีที่ต้องการระบุชื่อคลาสที่อ่านง่ายขึ้น เราสามารถใส่ label สำหรับคลาสได้

// %%
classDiagram
    class Animal["Animal with a label"]
    class Dog["Dog is animal"]

Animal <|-- Dog

// %% [markdown]
// ### การเพิ่มสมาชิกของคลาส
//
// Mermaid  มีรูปแบบในการเขียน code เพื่อระบุประเภทของสมาชิก ดังนี้
// 1. การระบุตัวแปร (variables, fields, หรือ prpoerties)  ทำได้โดยการเขียนชื่อตัวแปร และ/หรือ ชนิด
// 2. การระบุ method ทำได้โดยการเขียนชื่อ method ตามด้วยวงเล็บ
//
// เช่น
// > ```mermaid
// > classDiagram
// > class BankAccount
// > BankAccount : +String owner
// > BankAccount : +BigDecimal balance
// > BankAccount : +deposit(amount)
// > BankAccount : +withdrawal(amount)
// > ```

// %% [markdown]
// ให้นำ code ข้างบนมาใส่ลงใน code cell  แล้วรันเพื่อดูผลลัพธ์

// %%
classDiagram
 class BankAccount
 BankAccount : +String owner
 BankAccount : +BigDecimal balance
 BankAccount : +deposit(amount)
 BankAccount : +withdrawal(amount)

// %% [markdown]
// ### การระบุ return type สำหรับ method
// ในโปรแกรม oop ส่วนใหญ่จะเป็นภาษาแบบ strong type นั่นคือต้องมีการระบุชนิดสำหรับการส่งค่ากลับของ method อย่างชัดเจน
// วิธีการเขียนคือให้ใส่ชนิด return ไว้หลังวงเล็บของ method
// > ```diff
// > classDiagram
// > class BankAccount{
// >     +String owner
// >     +BigDecimal balance
// >     +deposit(amount) bool
// >     +withdrawal(amount) int
// > }
// > ```

// %% [markdown]
// เขียน code ตามข้างบนแล้วรันเพื่อดูผลลัพธ์

// %%
classDiagram
 class BankAccount{
     +String owner
     +BigDecimal balance
     +deposit(amount) bool
     +withdrawal(amount) int
 }

// %% [markdown]
// ### การระบุ visibility

// %% [markdown]
// การระบุ visibility ของสมาชิกในคลาส
//
// |สัญลักษณ์|visibility|
// |:--:|--|
// |+ |Public|
// |- |Private|
// |#| Protected|

// %% [markdown]
// คลาส Person เป็นตัวอย่างของคลาสคน ที่ไม่มีใครทราบชื่อ นามสกุล และอายของคนอื่น จนกว่าเขาจะบอกว่าเขาเป็นใคร อายุเท่าไหร่
//
// ถ้าเราอยากทราบข้อมูลส่วนบุคคล ให้ถามเขา (เช่นด้วยเมธอด  TellName, TellFullName และ TellAge เป็นต้น)
//
// ทดสอบไดอะแกรมต่อไปนี้โดยการรันในช่อง code cell ด้านล่าง
//
// ```diff
// >classDiagram
// >  class Person{
// >      -String name
// >      #String lastName
// >      -int age
// >      +TellName() String
// >      +TellFullName() String
// >      +TellAge() int
// >  }
// ```

// %%
classDiagram
  class Person{
      -String name
      #String lastName
      -int age
      +TellName() String
      +TellFullName() String
      +TellAge() int
  }

// %% [markdown]
// ---

// %% [markdown]
// ### การกำหนดเส้นเชื่อมโยงเพื่อแสดงความสัมพันธ์ระหว่างคลาส

// %% [markdown]
// มีรูปแบบการเขียนคือ
//
// [classA][Arrow][ClassB]

// %% [markdown]
// ใน mermaid diagram มีรูปแบบลูกศรที่รองรับแตกต่างกัน 8 รูปแบบ
//
// |Type|	Description|
// |---|--------|
// |<\|--	|Inheritance|
// |*--	|Composition|
// |o--	|Aggregation|
// |-->	|Association|
// |--	|Link (Solid)|
// |..>	|Dependency|
// |..|>	|Realization|
// |..	|Link (Dashed)|

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน code cell โดยกำหนดภาษาเป็น mermaid แล้วรันเพื่อดูผลที่ได้
// > ```diff
// > classDiagram
// > classA <|-- classB
// > classC *-- classD
// > classE o-- classF
// > classG <-- classH
// > classI -- classJ
// > classK <.. classL
// > classM <|.. classN
// > classO .. classP
// > ```

// %%
classDiagram
 classA <|-- classB
 classC *-- classD
 classE o-- classF
 classG <-- classH
 classI -- classJ
 classK <.. classL
 classM <|.. classN
 classO .. classP

// %% [markdown]
// เราสามารถกำหนดชื่อให้กับลูกศรได้

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน code cell โดยกำหนดภาษาเป็น mermaid แล้วรันเพื่อดูผลที่ได้
// > ```diff
// > classDiagram
// > classA --|> classB : Inheritance
// > classC --* classD : Composition
// > classE --o classF : Aggregation
// > classG --> classH : Association
// > classI -- classJ : Link(Solid)
// > classK ..> classL : Dependency
// > classM ..|> classN : Realization
// > classO .. classP : Link(Dashed)
// > ```

// %%
classDiagram
 classA --|> classB : Inheritance
 classC --* classD : Composition
 classE --o classF : Aggregation
 classG --> classH : Association
 classI -- classJ : Link(Solid)
 classK ..> classL : Dependency
 classM ..|> classN : Realization
 classO .. classP : Link(Dashed)

// %% [markdown]
// ---

// %% [markdown]
// ### Cardinality / Multiplicity on relations

// %% [markdown]
// รูปแบบต่างๆ ของ Cardinality
//
// |Symbol|Description|
// |:----:|----|
// |1 |Only 1|
// |0..1 |Zero or One|
// |1..* |One or more|
// |* |Many|
// |n |n (where n>1)|
// |0..n |zero to n (where n>1)|
// |1..n |one to n (where n>1)|

// %% [markdown]
// วิธีการระบุ cardilanity
//
// `[classA] "cardinality1" [Arrow] "cardinality2" [ClassB]:LabelText`

// %% [markdown]
// เขียน code ต่อไปนี้ลงใน mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >classDiagram
// >    Customer "1" --> "*" Ticket
// >    Student "1" --> "1..*" Course
// >    Galaxy --> "many" Star
// >```

// %%
   classDiagram
    Customer "1" --> "*" Ticket 
    Student "1" --> "1..*" Course 
    Galaxy --> "many" Star

// %% [markdown]
// ปรับปรุง code ด้านบน แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >classDiagram
// >-    Customer "1" --> "*" Ticket
// >+    Customer "1" --> "*" Ticket : Buy
// >-    Student "1" --> "1..*" Course
// >+    Student "1" --> "1..*" Course : Register
// >-    Galaxy --> "many" Star
// >+    Galaxy --> "many" Star : Contains
// >```

// %%
classDiagram
    Customer "1" --> "*" Ticket : Buy 
    Student "1" --> "1..*" Course : Register
    Galaxy --> "many" Star : Contains

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา class diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ## 1. ให้ค้นหา class diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ## 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น

// %%
classDiagram
    class User {
        email
        password
        resetPassword()
    }

    class ResetToken {
        expiration
    }

    class Audit {
        loginTimestamp
        method
    }

    class Admin {
        changeUserId(user)
        addUser()
        deleteUser()
    }

    class AuthPolicy {
        name
        logo
        url
        authenticate()
    }

    class Resource {
        type
        path
        name
    }

    User <|-- Admin
    User "1" --> "0..*" ResetToken
    User "1" --> "1..*" Audit
    AuthPolicy "1" --> "1" Resource
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="68e94a296430492d916c6a773861c704"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('68e94a296430492d916c6a773861c704');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_68e94a296430492d916c6a773861c704',
//                     `classDiagram
//     class User {
//         email
//         password
//         resetPassword()
//     }
//
//     class ResetToken {
//         expiration
//     }
//
//     class Audit {
//         loginTimestamp
//         method
//     }
//
//     class Admin {
//         changeUserId(user)
//         addUser()
//         deleteUser()
//     }
//
//     class AuthPolicy {
//         name
//         logo
//         url
//         authenticate()
//     }
//
//     class Resource {
//         type
//         path
//         name
//     }
//
//     User <|-- Admin
//     User "1" --> "0..*" ResetToken
//     User "1" --> "1..*" Audit
//     AuthPolicy "1" --> "1" Resource
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
classDiagram
    class Person {
        +firstName
        +surName
        +createWalk()
    }

    class Walk {
        +startTime
        +endTime
        +pickUp()
        +return()
        +end()
        +buy()
    }

    class MedicalSupplies {
        +name
        +price
        +description
        +orderLimit
        +pickUp()
        +return()
        +getPrice()
    }

    class Purchase {
        +Time
        +summ
        +summUp()
        +charge()
        +addSupplies()
    }

    Person "1" --> "0..*" Walk
    Walk "0..1" --> "*" MedicalSupplies
    Walk "1" --> "*" Purchase
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="078ee62c5606452b846aab78b29a68ac"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('078ee62c5606452b846aab78b29a68ac');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_078ee62c5606452b846aab78b29a68ac',
//                     `classDiagram
//     class Person {
//         +firstName
//         +surName
//         +createWalk()
//     }
//
//     class Walk {
//         +startTime
//         +endTime
//         +pickUp()
//         +return()
//         +end()
//         +buy()
//     }
//
//     class MedicalSupplies {
//         +name
//         +price
//         +description
//         +orderLimit
//         +pickUp()
//         +return()
//         +getPrice()
//     }
//
//     class Purchase {
//         +Time
//         +summ
//         +summUp()
//         +charge()
//         +addSupplies()
//     }
//
//     Person "1" --> "0..*" Walk
//     Walk "0..1" --> "*" MedicalSupplies
//     Walk "1" --> "*" Purchase
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
classDiagram
    class Delivery {
        # id: int
        + name: string
        + details: string
        + date: string
        + add()
        + update()
    }
    class Items {
        # id: int
        + name: string
        + description: string
        + price: string
        + datedue: string
        + add()
        + update()
    }
    class Customer {
        # id: int
        + name: string
        + age: string
        # username: string
        # password: string
        + create()
        + update
    }
    class Seller {
        + category: string
        # enableUser()
        # disableUser()
    }
    class Order {
        # id: int
        + date: string
        + item: string
        + payment: string
        + add()
        + update()
    }
    class Transaction {
        # id: int
        + details: string
        + date: string
        + update()
    }

    Delivery "1..*" --> "1" Order
    Items "1..*" --> "1" Order
    Items "1..*" --> "1" Seller
    Customer "1..*" --> "1" Transaction
    Transaction "1..*" --> "1" Seller
    Order "1..*" --> "1" Customer
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="f87e0c950dcf46a19fb6be90242ea5ea"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('f87e0c950dcf46a19fb6be90242ea5ea');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_f87e0c950dcf46a19fb6be90242ea5ea',
//                     `classDiagram
//     class Delivery {
//         # id: int
//         + name: string
//         + details: string
//         + date: string
//         + add()
//         + update()
//     }
//     class Items {
//         # id: int
//         + name: string
//         + description: string
//         + price: string
//         + datedue: string
//         + add()
//         + update()
//     }
//     class Customer {
//         # id: int
//         + name: string
//         + age: string
//         # username: string
//         # password: string
//         + create()
//         + update
//     }
//     class Seller {
//         + category: string
//         # enableUser()
//         # disableUser()
//     }
//     class Order {
//         # id: int
//         + date: string
//         + item: string
//         + payment: string
//         + add()
//         + update()
//     }
//     class Transaction {
//         # id: int
//         + details: string
//         + date: string
//         + update()
//     }
//
//     Delivery "1..*" --> "1" Order
//     Items "1..*" --> "1" Order
//     Items "1..*" --> "1" Seller
//     Customer "1..*" --> "1" Transaction
//     Transaction "1..*" --> "1" Seller
//     Order "1..*" --> "1" Customer
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ## 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// ![image.png](attachment:image.png)
